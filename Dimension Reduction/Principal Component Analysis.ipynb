# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading

# %%
# !kaggle datasets download -d uciml/breast-cancer-wisconsin-data

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
diagnosis = df["diagnosis"]
df.drop(["diagnosis", "Unnamed: 32"], axis = 1, inplace = True)

# %%
df.isna().sum()
# Out:
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# No NaNs and only numbers in df, that's perfect. We've got a lot of features so let's do a PCA.

# %% [markdown]
# # Quick Normalization

# %% [markdown]
# It is usually needed to normalize before doing a PCA, so that all features be of equal importance in the shape of the data scatter plot.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df)

# %%
normalized_df = pd.DataFrame(X, columns = df.columns, index = df.index)

# %%
normalized_df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0 -0.236405     1.097064     -2.073335        1.269934   0.984375
# 1 -0.236403     1.829821     -0.353632        1.685955   1.908708
# 2  0.431741     1.579888      0.456187        1.566503   1.558884
# 3  0.432121    -0.768909      0.253732       -0.592687  -0.764464
# 4  0.432201     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
normalized_df.describe()
# Out:
#                  id   radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean   1.248757e-17 -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.430790e-01 -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -2.361897e-01 -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.358950e-01 -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%   -1.725930e-01  4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    7.052629e+00  3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# ...

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA() # PCA(n_components = 3)

# %%
pca.fit(normalized_df)
# Out:
# PCA()

# %%
projection = pca.transform(normalized_df)
projection.shape
# Out:
# (569, 31)

# %% [markdown]
# # Percentages of variance explained by each component

# %%
n = pca.n_components_
grid = np.arange(1, n + 1)
evr = pca.explained_variance_ratio_ # explained variance
plt.bar(grid[:3], evr[:3])
plt.xlabel('Component')
plt.title("% Explained Variance")
# Out:
# Text(0.5, 1.0, '% Explained Variance')

# %% [markdown]
# These 3 first components explain approximately 70% of the variance. That is rather interesting.

# %% [markdown]
# # To go further

# %% [markdown]
# Very nice example of how PCA can be used to determine key features to detect cancers here : https://www.kaggle.com/code/jeanvalere/pca-to-the-breast-cancer-data-set

# %% [markdown]
# (This Kaggle notebook is originally from Jahir Moreno. I copied it to be sure it wouldn't disappear from Kaggle.)
